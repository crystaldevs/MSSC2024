# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
file=open("inter_300.DAT")
lines=file.readlines()
mu=[]
carrier=[]
v= 1.139E-20
for line in lines:
    split=line.split()
    x1=float(split[2])
    x2=float(split[0])
    carrier.append(x1/v)
    mu.append(x2)
file.close

print(carrier)
# Out:
# [3.2598770851624232e+22, 3.251097453906936e+22, 3.2423178226514486e+22, 3.23441615452151e+22, 3.2265144863915715e+22, 3.218612818261633e+22, 3.2107111501316944e+22, 3.202809482001756e+22, 3.195785776997366e+22, 3.1878841088674277e+22, 3.1808604038630377e+22, 3.172958735733099e+22, 3.1659350307287094e+22, 3.1589113257243198e+22, 3.1518876207199298e+22, 3.1448639157155398e+22, 3.1378402107111498e+22, 3.131694468832309e+22, 3.124670763827919e+22, 3.1176470588235297e+22, 3.111501316944688e+22, 3.1044776119402985e+22, 3.098331870061457e+22, 3.0913081650570676e+22, 3.0851624231782264e+22, 3.0781387181738368e+22, 3.0719929762949955e+22, 3.0658472344161542e+22, 3.0588235294117647e+22, 3.0526777875329234e+22, 3.0465320456540826e+22, 3.0395083406496925e+22, 3.0333625987708517e+22, 3.0263388937664617e+22, 3.020193151887621e+22, 3.013169446883231e+22, 3.006145741878841e+22, 3e+22, 2.9938542581211587e+22, 2.987708516242318e+22, 2.981562774363477e+22, 2.976294995610184e+22, 2.9710272168568916e+22,
# ...

# %%
index_carrier=carrier.index(-1.1071115013169445e+20)
#print(index_carrier)

# %%
mu_correspnding=mu[index_carrier]

# %%
mu_correspnding
# Out:
# -1.66
